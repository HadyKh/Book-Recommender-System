# %%
import warnings
warnings.filterwarnings('ignore')
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
import re
import nltk
import random
import numpy as np
import pandas as pd
from urllib import request
from random import randint
#from wordcloud import WordCloud
from nltk import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn import preprocessing
from nltk.stem import WordNetLemmatizer

# %%
#loading dataset and removing unwanted features
dataset = pd.read_csv(f'Book_summary.csv', encoding= 'unicode_escape')
dataset = dataset.drop('Publication Date', axis=1)
dataset = dataset.drop('Wikibedia ID', axis=1)
dataset = dataset.drop('Freebase ID', axis=1)
dataset
# Out:
#                                               Book title         Book author  \
# 0                                            Animal Farm       George Orwell
# 1                                     A Clockwork Orange     Anthony Burgess
# 2                                             The Plague        Albert Camus
# 3              An Enquiry Concerning Human Understanding          David Hume
# 4                                   A Fire Upon the Deep        Vernor Vinge
# ...                                                  ...                 ...
# 16554                                     Under Wildwood         Colin Meloy
# 16555                                  Transfer of Power         Vince Flynn
# 16556                                            Decoded               Jay-Z
# 16557  America Again: Re-becoming The Greatness We Ne...     Stephen Colbert
# 16558                                          Poor Folk  Fyodor Dostoyevsky
#
#                                                    Genre  \
# 0      {"/m/016lj8": "Roman à clef", "/m/06nbt": "Sat...
# 1      {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2      {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3                                                    NaN
# 4      {"/m/03lrw": "Hard science fiction", "/m/06n90...
# ...                                                  ...
# 16554                                                NaN
# 16555   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16556                       {"/m/0xdf": "Autobiography"}
# 16557                                                NaN
# 16558  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                  Summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 4 columns]

# %%
def cleaned_text(raw_text):
    raw_text = re.findall(r"[a-zA-Z]+", raw_text)
    raw_text = " ".join(raw_text).lower()
    tokens = word_tokenize(raw_text)
    stop_words = stopwords.words("english")
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    
    return tokens

# %%
def convert_list_to_string(org_list, seperator=' '):
    """ Convert list to string, by joining all item in list with given separator.
        Returns the concatenated string """
    return seperator.join(org_list)

# %%
#check for nulls and removing nans
dataset.isnull().sum()
dataset = dataset.dropna(axis = 0)

# %%
dataset.insert(loc=3,
          column='Tokens',
          value="")
for index, row in dataset.iterrows():
    tokens = cleaned_text(str(row['Summary']))
    row['Tokens']=set(tokens)
    # Convert list of strings to string
    row['Tokens'] = convert_list_to_string(tokens)

dataset = pd.DataFrame(dataset)
dataset = dataset.sample(frac=1).reset_index(drop=True)
dataset
# Out:
#                                               Book title        Book author  \
# 0                                       Dragon and Thief       Timothy Zahn
# 1                                            Poor Things      Alasdair Gray
# 2                                      Sharpe's Fortress   Bernard Cornwell
# 3                                       The Folding Star  Alan Hollinghurst
# 4      Fast Food Nation: The Dark Side of the All-Ame...     Eric Schlosser
# ...                                                  ...                ...
# 12050                                       The Traveler  John Twelve Hawks
# 12051                                            Babbitt     Sinclair Lewis
# 12052                 Conan: Scourge of the Bloody Coast  Leonard Carpenter
# 12053                                 Thirty-Three Teeth    Colin Cotterill
# 12054                                   The Family Trade     Charles Stross
#
#                                                    Genre  \
# 0                {"/m/03mfnf": "Young adult literature"}
# 1      {"/m/014dfn": "Speculative fiction", "/m/02p0s...
# 2                       {"/m/0hwxm": "Historical novel"}
# 3                                  {"/m/05hgj": "Novel"}
# 4                            {"/m/05h83": "Non-fiction"}
# ...                                                  ...
# 12050                    {"/m/06n90": "Science Fiction"}
# 12051  {"/m/06nbt": "Satire", "/m/02xlf": "Fiction", ...
# 12052  {"/m/0dz8b": "Sword and sorcery", "/m/01hmnh":...
# 12053  {"/m/0lsxr": "Crime Fiction", "/m/02n4kr": "My...
# 12054  {"/m/0mz2": "Alternate history", "/m/06n90": "...
#
#                                                   Tokens  \
# 0      two year space advance team shontine k da reac...
# 1      main body work centre bella baxter woman whose...
# 2      sir arthur wellesley army closing retreating m...
# 3      novel story english gay man edward manner disa...
# 4      schlosser open book ironic delivery pizza top ...
# ...                                                  ...
# 12050  shadow modern society epic battle fought one w...
# 12051  lewis criticized congratulated unorthodox writ...
# 12052  conan piratical alias amra continues develop p...
# 12053  malay black bear vanishes cage zoo garden vien...
# 12054  miriam adoptive mother give shoebox filled ite...
#
#                                                  Summary
# 0       After two years in space, the advance team of...
# 1       The main body of the work centres on Bella Ba...
# 2       It is 1803 and Sir Arthur Wellesley??s army ...
# 3       The novel is the story of an English gay man,...
# 4       Schlosser opens the book with the ironic deli...
# ...                                                  ...
# 12050   In the shadows of modern society an epic batt...
# 12051   Lewis has been both criticized and congratula...
# 12052   Conan, under his piratical alias of Amra, con...
# 12053   When the Malay Black bear vanishes from its c...
# 12054   Miriam's adoptive mother gives her a shoebox ...
#
# [12055 rows x 5 columns]
