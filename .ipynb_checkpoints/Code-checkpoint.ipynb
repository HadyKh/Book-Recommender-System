# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(f'Book_summary.csv', encoding= 'unicode_escape')

# %%
dataset
# Out:
#        Wikibedia ID Freebase ID  \
# 0               620     /m/0hhy
# 1               843     /m/0k36
# 2               986     /m/0ldx
# 3              1756     /m/0sww
# 4              2080     /m/0wkt
# ...             ...         ...
# 16554      36934824  /m/0m0p0hr
# 16555      37054020  /m/04f1nbs
# 16556      37122323  /m/0n5236t
# 16557      37132319  /m/0n4bqb1
# 16558      37159503   /m/073nkd
#
#                                               Book title         Book author  \
# 0                                            Animal Farm       George Orwell
# 1                                     A Clockwork Orange     Anthony Burgess
# 2                                             The Plague        Albert Camus
# 3              An Enquiry Concerning Human Understanding          David Hume
# 4                                   A Fire Upon the Deep        Vernor Vinge
# ...                                                  ...                 ...
# ...

# %%
print(f"Column name: 'Wikibedia ID',      number of Na: {dataset['Wikibedia ID'].isna().sum()}")
print(f"Column name: 'Freebase ID',       number of Na: {dataset['Freebase ID'].isna().sum()}")
print(f"Column name: 'Book title',        number of Na: {dataset['Book title'].isna().sum()}")
print(f"Column name: 'Book author',       number of Na: {dataset['Book author'].isna().sum()}")
print(f"Column name: 'Publication Date',  number of Na: {dataset['Publication Date'].isna().sum()}")
print(f"Column name: 'Genre',             number of Na: {dataset['Genre'].isna().sum()}")
print(f"Column name: 'Summary',           number of Na: {dataset['Summary'].isna().sum()}")
# Out:
# Column name: 'Wikibedia ID',      number of Na: 0
# Column name: 'Freebase ID',       number of Na: 0
# Column name: 'Book title',        number of Na: 0
# Column name: 'Book author',       number of Na: 2382
# Column name: 'Publication Date',  number of Na: 5610
# Column name: 'Genre',             number of Na: 3718
# Column name: 'Summary',           number of Na: 0
